# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("Titanic-Dataset.csv")
df.drop(columns=["PassengerId","Name","Ticket","Fare","Cabin"],inplace = True)
# ******************************************************
df["Age"].fillna(value=df["Age"].median(),inplace=True)
df["Embarked"].fillna(value="S",inplace = True)
# ******************************************************
le = LabelEncoder()
df["Sex"]= le.fit_transform(df["Sex"])
df["Embarked"]=le.fit_transform(df["Embarked"])
# ******************************************************
q1=df["Age"].quantile(0.25)
q3=df["Age"].quantile(0.75)
iqr  = q3-q1
lf = q1-(1.5*iqr)
uf = q3+(1.5*iqr)
df["Age"] = np.where(df["Age"]<lf,lf,df["Age"])
df["Age"] = np.where(df["Age"]>uf,uf,df["Age"])
# ******************************************************
y = df["Survived"]
x = df.drop(columns="Survived")
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=88) 


rf = RandomForestClassifier(n_estimators = 250,criterion  = "entropy",max_depth=8,min_samples_split=50, random_state=88)

# %%
st.title("Titanic  Crash Prediction")
@st.cache_data
